# %%
# !pip install ultralytics

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="BriTuXpfVKyrl8IfhdLe")
project = rf.workspace("harshils-workspace").project("archaeological-site-mapping")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !ls
# Out:
# Archaeological-Site-Mapping-6  sample_data  yolov8n-seg.pt

# %%
# !ls Archaeological-Site-Mapping-6/
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/Archaeological-Site-Mapping-6/data.yaml",
    epochs=20,
    imgsz=640
)
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")

model.predict(
    source="/content/Archaeological-Site-Mapping-6/test/images",
    save=True
)
# Out:
# image 1/12 /content/Archaeological-Site-Mapping-6/test/images/hampi_02_jpg.rf.041496686effbd578c1336b5b3de628c.jpg: 640x640 34 otherss, 4 ruinss, 8 vegetations, 7.3ms
# image 2/12 /content/Archaeological-Site-Mapping-6/test/images/hampi_19_jpg.rf.7fbf7b14f282c9638a8397e44016c79b.jpg: 640x640 3 vegetations, 11.0ms
# image 3/12 /content/Archaeological-Site-Mapping-6/test/images/khajuraho_05_jpg.rf.ccb51394ef8daf3a4682a5fd5277a312.jpg: 640x640 2 otherss, 11 vegetations, 9.3ms
# image 4/12 /content/Archaeological-Site-Mapping-6/test/images/khajuraho_20_jpg.rf.43f525eb3f5064d2c4cfa7bdab17eea7.jpg: 640x640 14 vegetations, 9.2ms
# image 5/12 /content/Archaeological-Site-Mapping-6/test/images/khajuraho_36_jpg.rf.12e451236025cc8bc582a86259aa16e0.jpg: 640x640 1 ruins, 21 vegetations, 8.2ms
# image 6/12 /content/Archaeological-Site-Mapping-6/test/images/nalanda_07_jpg.rf.8eb08ce5d9c43770f55f122c27939fcd.jpg: 640x640 2 ruinss, 9.7ms
# ...

# %%
import glob
from IPython.display import Image, display

images = glob.glob("runs/detect/predict/*.jpg")

for img in images[:5]:   # show first 5 images
    display(Image(filename=img))

# %%
# !ls /content/Archaeological-Site-Mapping-6/train/labels | head
# Out:
# hampi_03_jpg.rf.15f09a3e7c43faad786ba266f1ca0055.txt
# hampi_03_jpg.rf.f27d84ae3a3fa32374ca905d58000870.txt
# hampi_03_jpg.rf.f95d0e2c8750f3ee920ec3f6960edcc9.txt
# hampi_04_jpg.rf.1d87586062caa84d23bc29e36b778dfc.txt
# hampi_04_jpg.rf.81337da86415a845634bd35cbf8fbc72.txt
# hampi_04_jpg.rf.f64da02b081b89548e8b3c32b1b89241.txt
# hampi_05_jpg.rf.01ea1da33bd9d7202e81896d2fd36bb4.txt
# hampi_05_jpg.rf.2f2dccac7d25ed3786371adb530e503e.txt
# hampi_05_jpg.rf.ddfbf791a4183a42539e961e0d7f210c.txt
# hampi_06_jpg.rf.334ffdcdde2a33e4c45cc9cf6e394de2.txt

# %%
from IPython.display import Image
Image("/content/runs/detect/train/results.png")

# %%
# !cat /content/Archaeological-Site-Mapping-6/data.yaml
# Out:
# names:
# - boulders
# - others
# - ruins
# - structures
# - vegetation
# nc: 5
# roboflow:
#   license: CC BY 4.0
#   project: archaeological-site-mapping
#   url: https://universe.roboflow.com/harshils-workspace/archaeological-site-mapping/dataset/6
#   version: 6
#   workspace: harshils-workspace
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
import cv2
import matplotlib.pyplot as plt
import random
import os

img_dir = "/content/Archaeological-Site-Mapping-6/train/images"
label_dir = "/content/Archaeological-Site-Mapping-6/train/labels"

img_file = random.choice(os.listdir(img_dir))
img = cv2.imread(f"{img_dir}/{img_file}")

h, w = img.shape[:2]

label_file = img_file.replace(".jpg",".txt").replace(".png",".txt")

with open(f"{label_dir}/{label_file}") as f:
    for line in f:
        c,x,y,bw,bh = map(float,line.split())
        x1 = int((x-bw/2)*w)
        y1 = int((y-bh/2)*h)
        x2 = int((x+bw/2)*w)
        y2 = int((y+bh/2)*h)
        cv2.rectangle(img,(x1,y1),(x2,y2),(0,255,0),2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(639.5), np.float64(-0.5))

# %%
# !ls /content/Archaeological-Site-Mapping-6/train/images | wc -l
# Out:
# 270
